# %%
import pandas as pd
import numpy as np
from operator import getitem
from functools import partial

# %%
full_df = pd.read_json('c.json')
# full_df = full_df.drop(['timezones', 'translations', 'states', 'emojiU', 'native', 'tld', 'id'], axis = 1)
full_df.head(50)
# Out:
#      id                              name iso3 iso2 phone_code  \
# 0     1                       Afghanistan  AFG   AF         93
# 1     2                     Aland Islands  ALA   AX    +358-18
# 2     3                           Albania  ALB   AL        355
# 3     4                           Algeria  DZA   DZ        213
# 4     5                    American Samoa  ASM   AS     +1-684
# 5     6                           Andorra  AND   AD        376
# 6     7                            Angola  AGO   AO        244
# 7     8                          Anguilla  AIA   AI     +1-264
# 8     9                        Antarctica  ATA   AQ
# 9    10               Antigua And Barbuda  ATG   AG     +1-268
# 10   11                         Argentina  ARG   AR         54
# 11   12                           Armenia  ARM   AM        374
# 12   13                             Aruba  ABW   AW        297
# 13   14                         Australia  AUS   AU         61
# 14   15                           Austria  AUT   AT         43
# 15   16                        Azerbaijan  AZE   AZ        994
# 16   17                       Bahamas The  BHS   BS     +1-242
# 17   18                           Bahrain  BHR   BH        973
# 18   19                        Bangladesh  BGD   BD        880
# 19   20                          Barbados  BRB   BB     +1-246
# 20   21                           Belarus  BLR   BY        375
# 21   22                           Belgium  BEL   BE         32
# 22   23                            Belize  BLZ   BZ        501
# 23   24                             Benin  BEN   BJ        229
# 24   25                           Bermuda  BMU   BM     +1-441
# 25   26                            Bhutan  BTN   BT        975
# 26   27                           Bolivia  BOL   BO        591
# 27  155  Bonaire, Sint Eustatius and Saba  BES   BQ        599
# 28   28            Bosnia and Herzegovina  BIH   BA        387
# 29   29                          Botswana  BWA   BW        267
# 30   30                     Bouvet Island  BVT   BV       0055
# 31   31                            Brazil  BRA   BR         55
# 32   32    British Indian Ocean Territory  IOT   IO        246
# 33   33                            Brunei  BRN   BN        673
# 34   34                          Bulgaria  BGR   BG        359
# 35   35                      Burkina Faso  BFA   BF        226
# 36   36                           Burundi  BDI   BI        257
# 37   37                          Cambodia  KHM   KH        855
# 38   38                          Cameroon  CMR   CM        237
# 39   39                            Canada  CAN   CA          1
# 40   40                        Cape Verde  CPV   CV        238
# 41   41                    Cayman Islands  CYM   KY     +1-345
# 42   42          Central African Republic  CAF   CF        236
# 43   43                              Chad  TCD   TD        235
# 44   44                             Chile  CHL   CL         56
# 45   45                             China  CHN   CN         86
# 46   46                  Christmas Island  CXR   CX         61
# 47   47           Cocos (Keeling) Islands  CCK   CC         61
# 48   48                          Colombia  COL   CO         57
# 49   49                           Comoros  COM   KM        269
#
#                 capital currency currency_symbol  tld  \
# 0                 Kabul      AFN               ؋  .af
# 1             Mariehamn      EUR               €  .ax
# 2                Tirana      ALL             Lek  .al
# 3               Algiers      DZD              دج  .dz
# 4             Pago Pago      USD               $  .as
# 5      Andorra la Vella      EUR               €  .ad
# 6                Luanda      AOA              Kz  .ao
# 7            The Valley      XCD               $  .ai
# 8                                              $  .aq
# 9            St. John's      XCD               $  .ag
# 10         Buenos Aires      ARS               $  .ar
# 11              Yerevan      AMD               ֏  .am
# 12           Oranjestad      AWG               ƒ  .aw
# 13             Canberra      AUD               $  .au
# 14               Vienna      EUR               €  .at
# 15                 Baku      AZN               m  .az
# 16               Nassau      BSD              B$  .bs
# 17               Manama      BHD            .د.ب  .bh
# 18                Dhaka      BDT               ৳  .bd
# 19           Bridgetown      BBD            Bds$  .bb
# 20                Minsk      BYN              Br  .by
# 21             Brussels      EUR               €  .be
# 22             Belmopan      BZD               $  .bz
# 23           Porto-Novo      XOF             CFA  .bj
# 24             Hamilton      BMD               $  .bm
# 25              Thimphu      BTN             Nu.  .bt
# 26                Sucre      BOB             Bs.  .bo
# 27           Kralendijk      USD               $  .an
# 28             Sarajevo      BAM              KM  .ba
# 29             Gaborone      BWP               P  .bw
# 30                           NOK              kr  .bv
# 31             Brasilia      BRL              R$  .br
# 32         Diego Garcia      USD               $  .io
# 33  Bandar Seri Begawan      BND              B$  .bn
# 34                Sofia      BGN             Лв.  .bg
# 35          Ouagadougou      XOF             CFA  .bf
# 36            Bujumbura      BIF             FBu  .bi
# 37           Phnom Penh      KHR             KHR  .kh
# 38              Yaounde      XAF            FCFA  .cm
# 39               Ottawa      CAD               $  .ca
# 40                Praia      CVE               $  .cv
# 41          George Town      KYD               $  .ky
# 42               Bangui      XAF            FCFA  .cf
# 43            N'Djamena      XAF            FCFA  .td
# 44             Santiago      CLP               $  .cl
# 45              Beijing      CNY               ¥  .cn
# 46     Flying Fish Cove      AUD               $  .cx
# 47          West Island      AUD               $  .cc
# 48               Bogota      COP               $  .co
# 49               Moroni      KMF              CF  .km
#
#                             native    region                  subregion  \
# 0                        افغانستان      Asia              Southern Asia
# 1                            Åland    Europe            Northern Europe
# 2                        Shqipëria    Europe            Southern Europe
# 3                          الجزائر    Africa            Northern Africa
# 4                   American Samoa   Oceania                  Polynesia
# 5                          Andorra    Europe            Southern Europe
# 6                           Angola    Africa              Middle Africa
# 7                         Anguilla  Americas                  Caribbean
# 8                       Antarctica     Polar
# 9              Antigua and Barbuda  Americas                  Caribbean
# 10                       Argentina  Americas              South America
# 11                        Հայաստան      Asia               Western Asia
# 12                           Aruba  Americas                  Caribbean
# 13                       Australia   Oceania  Australia and New Zealand
# 14                      Österreich    Europe             Western Europe
# 15                      Azərbaycan      Asia               Western Asia
# 16                         Bahamas  Americas                  Caribbean
# 17                        ‏البحرين      Asia               Western Asia
# 18                      Bangladesh      Asia              Southern Asia
# 19                        Barbados  Americas                  Caribbean
# 20                       Белару́сь    Europe             Eastern Europe
# 21                          België    Europe             Western Europe
# 22                          Belize  Americas            Central America
# 23                           Bénin    Africa             Western Africa
# 24                         Bermuda  Americas           Northern America
# 25                       ʼbrug-yul      Asia              Southern Asia
# 26                         Bolivia  Americas              South America
# 27             Caribisch Nederland  Americas                  Caribbean
# 28             Bosna i Hercegovina    Europe            Southern Europe
# 29                        Botswana    Africa            Southern Africa
# 30                       Bouvetøya
# 31                          Brasil  Americas              South America
# 32  British Indian Ocean Territory    Africa             Eastern Africa
# 33        Negara Brunei Darussalam      Asia         South-Eastern Asia
# 34                        България    Europe             Eastern Europe
# 35                    Burkina Faso    Africa             Western Africa
# 36                         Burundi    Africa             Eastern Africa
# 37                       Kâmpŭchéa      Asia         South-Eastern Asia
# 38                        Cameroon    Africa              Middle Africa
# 39                          Canada  Americas           Northern America
# 40                      Cabo Verde    Africa             Western Africa
# 41                  Cayman Islands  Americas                  Caribbean
# 42          Ködörösêse tî Bêafrîka    Africa              Middle Africa
# 43                           Tchad    Africa              Middle Africa
# 44                           Chile  Americas              South America
# 45                              中国      Asia               Eastern Asia
# 46                Christmas Island   Oceania  Australia and New Zealand
# 47         Cocos (Keeling) Islands   Oceania  Australia and New Zealand
# 48                        Colombia  Americas              South America
# 49                          Komori    Africa             Eastern Africa
#
#                                             timezones  \
# 0   [{'zoneName': 'Asia/Kabul', 'gmtOffset': 16200...
# 1   [{'zoneName': 'Europe/Mariehamn', 'gmtOffset':...
# 2   [{'zoneName': 'Europe/Tirane', 'gmtOffset': 36...
# 3   [{'zoneName': 'Africa/Algiers', 'gmtOffset': 3...
# 4   [{'zoneName': 'Pacific/Pago_Pago', 'gmtOffset'...
# 5   [{'zoneName': 'Europe/Andorra', 'gmtOffset': 3...
# 6   [{'zoneName': 'Africa/Luanda', 'gmtOffset': 36...
# 7   [{'zoneName': 'America/Anguilla', 'gmtOffset':...
# 8   [{'zoneName': 'Antarctica/Casey', 'gmtOffset':...
# 9   [{'zoneName': 'America/Antigua', 'gmtOffset': ...
# 10  [{'zoneName': 'America/Argentina/Buenos_Aires'...
# 11  [{'zoneName': 'Asia/Yerevan', 'gmtOffset': 144...
# 12  [{'zoneName': 'America/Aruba', 'gmtOffset': -1...
# 13  [{'zoneName': 'Antarctica/Macquarie', 'gmtOffs...
# 14  [{'zoneName': 'Europe/Vienna', 'gmtOffset': 36...
# 15  [{'zoneName': 'Asia/Baku', 'gmtOffset': 14400,...
# 16  [{'zoneName': 'America/Nassau', 'gmtOffset': -...
# 17  [{'zoneName': 'Asia/Bahrain', 'gmtOffset': 108...
# 18  [{'zoneName': 'Asia/Dhaka', 'gmtOffset': 21600...
# 19  [{'zoneName': 'America/Barbados', 'gmtOffset':...
# 20  [{'zoneName': 'Europe/Minsk', 'gmtOffset': 108...
# 21  [{'zoneName': 'Europe/Brussels', 'gmtOffset': ...
# 22  [{'zoneName': 'America/Belize', 'gmtOffset': -...
# 23  [{'zoneName': 'Africa/Porto-Novo', 'gmtOffset'...
# 24  [{'zoneName': 'Atlantic/Bermuda', 'gmtOffset':...
# 25  [{'zoneName': 'Asia/Thimphu', 'gmtOffset': 216...
# 26  [{'zoneName': 'America/La_Paz', 'gmtOffset': -...
# 27  [{'zoneName': 'America/Anguilla', 'gmtOffset':...
# 28  [{'zoneName': 'Europe/Sarajevo', 'gmtOffset': ...
# 29  [{'zoneName': 'Africa/Gaborone', 'gmtOffset': ...
# 30  [{'zoneName': 'Europe/Oslo', 'gmtOffset': 3600...
# 31  [{'zoneName': 'America/Araguaina', 'gmtOffset'...
# 32  [{'zoneName': 'Indian/Chagos', 'gmtOffset': 21...
# 33  [{'zoneName': 'Asia/Brunei', 'gmtOffset': 2880...
# 34  [{'zoneName': 'Europe/Sofia', 'gmtOffset': 720...
# 35  [{'zoneName': 'Africa/Ouagadougou', 'gmtOffset...
# 36  [{'zoneName': 'Africa/Bujumbura', 'gmtOffset':...
# 37  [{'zoneName': 'Asia/Phnom_Penh', 'gmtOffset': ...
# 38  [{'zoneName': 'Africa/Douala', 'gmtOffset': 36...
# 39  [{'zoneName': 'America/Atikokan', 'gmtOffset':...
# 40  [{'zoneName': 'Atlantic/Cape_Verde', 'gmtOffse...
# 41  [{'zoneName': 'America/Cayman', 'gmtOffset': -...
# 42  [{'zoneName': 'Africa/Bangui', 'gmtOffset': 36...
# 43  [{'zoneName': 'Africa/Ndjamena', 'gmtOffset': ...
# 44  [{'zoneName': 'America/Punta_Arenas', 'gmtOffs...
# 45  [{'zoneName': 'Asia/Shanghai', 'gmtOffset': 28...
# 46  [{'zoneName': 'Indian/Christmas', 'gmtOffset':...
# 47  [{'zoneName': 'Indian/Cocos', 'gmtOffset': 234...
# 48  [{'zoneName': 'America/Bogota', 'gmtOffset': -...
# 49  [{'zoneName': 'Indian/Comoro', 'gmtOffset': 10...
#
#                                          translations   latitude   longitude  \
# 0   {'br': 'Afeganistão', 'pt': 'Afeganistão', 'nl...  33.000000   65.000000
# 1   {'br': 'Ilhas de Aland', 'pt': 'Ilhas de Aland...  60.116667   19.900000
# 2   {'br': 'Albânia', 'pt': 'Albânia', 'nl': 'Alba...  41.000000   20.000000
# 3   {'br': 'Argélia', 'pt': 'Argélia', 'nl': 'Alge...  28.000000    3.000000
# 4   {'br': 'Samoa Americana', 'pt': 'Samoa America... -14.333333 -170.000000
# 5   {'br': 'Andorra', 'pt': 'Andorra', 'nl': 'Ando...  42.500000    1.500000
# 6   {'br': 'Angola', 'pt': 'Angola', 'nl': 'Angola... -12.500000   18.500000
# 7   {'br': 'Anguila', 'pt': 'Anguila', 'nl': 'Angu...  18.250000  -63.166667
# 8   {'br': 'Antártida', 'pt': 'Antárctida', 'nl': ... -74.650000    4.480000
# 9   {'br': 'Antígua e Barbuda', 'pt': 'Antígua e B...  17.050000  -61.800000
# 10  {'br': 'Argentina', 'pt': 'Argentina', 'nl': '... -34.000000  -64.000000
# 11  {'br': 'Armênia', 'pt': 'Arménia', 'nl': 'Arme...  40.000000   45.000000
# 12  {'br': 'Aruba', 'pt': 'Aruba', 'nl': 'Aruba', ...  12.500000  -69.966667
# 13  {'br': 'Austrália', 'pt': 'Austrália', 'nl': '... -27.000000  133.000000
# 14  {'br': 'áustria', 'pt': 'áustria', 'nl': 'Oost...  47.333333   13.333333
# 15  {'br': 'Azerbaijão', 'pt': 'Azerbaijão', 'nl':...  40.500000   47.500000
# 16  {'br': 'Bahamas', 'pt': 'Baamas', 'nl': 'Baham...  24.250000  -76.000000
# 17  {'br': 'Bahrein', 'pt': 'Barém', 'nl': 'Bahrei...  26.000000   50.550000
# 18  {'br': 'Bangladesh', 'pt': 'Bangladeche', 'nl'...  24.000000   90.000000
# 19  {'br': 'Barbados', 'pt': 'Barbados', 'nl': 'Ba...  13.166667  -59.533333
# 20  {'br': 'Bielorrússia', 'pt': 'Bielorrússia', '...  53.000000   28.000000
# 21  {'br': 'Bélgica', 'pt': 'Bélgica', 'nl': 'Belg...  50.833333    4.000000
# 22  {'br': 'Belize', 'pt': 'Belize', 'nl': 'Belize...  17.250000  -88.750000
# 23  {'br': 'Benin', 'pt': 'Benim', 'nl': 'Benin', ...   9.500000    2.250000
# 24  {'br': 'Bermudas', 'pt': 'Bermudas', 'nl': 'Be...  32.333333  -64.750000
# 25  {'br': 'Butão', 'pt': 'Butão', 'nl': 'Bhutan',...  27.500000   90.500000
# 26  {'br': 'Bolívia', 'pt': 'Bolívia', 'nl': 'Boli... -17.000000  -65.000000
# 27  {'br': 'Bonaire', 'pt': 'Bonaire', 'fa': 'بونی...  12.150000  -68.266667
# 28  {'br': 'Bósnia e Herzegovina', 'pt': 'Bósnia e...  44.000000   18.000000
# 29  {'br': 'Botsuana', 'pt': 'Botsuana', 'nl': 'Bo... -22.000000   24.000000
# 30  {'br': 'Ilha Bouvet', 'pt': 'Ilha Bouvet', 'nl... -54.433333    3.400000
# 31  {'br': 'Brasil', 'pt': 'Brasil', 'nl': 'Brazil... -10.000000  -55.000000
# 32  {'br': 'Território Britânico do Oceano íÍdico'...  -6.000000   71.500000
# 33  {'br': 'Brunei', 'pt': 'Brunei', 'nl': 'Brunei...   4.500000  114.666667
# 34  {'br': 'Bulgária', 'pt': 'Bulgária', 'nl': 'Bu...  43.000000   25.000000
# 35  {'br': 'Burkina Faso', 'pt': 'Burquina Faso', ...  13.000000   -2.000000
# 36  {'br': 'Burundi', 'pt': 'Burúndi', 'nl': 'Buru...  -3.500000   30.000000
# 37  {'br': 'Camboja', 'pt': 'Camboja', 'nl': 'Camb...  13.000000  105.000000
# 38  {'br': 'Camarões', 'pt': 'Camarões', 'nl': 'Ka...   6.000000   12.000000
# 39  {'br': 'Canadá', 'pt': 'Canadá', 'nl': 'Canada...  60.000000  -95.000000
# 40  {'br': 'Cabo Verde', 'pt': 'Cabo Verde', 'nl':...  16.000000  -24.000000
# 41  {'br': 'Ilhas Cayman', 'pt': 'Ilhas Caimão', '...  19.500000  -80.500000
# 42  {'br': 'República Centro-Africana', 'pt': 'Rep...   7.000000   21.000000
# 43  {'br': 'Chade', 'pt': 'Chade', 'nl': 'Tsjaad',...  15.000000   19.000000
# 44  {'br': 'Chile', 'pt': 'Chile', 'nl': 'Chili', ... -30.000000  -71.000000
# 45  {'br': 'China', 'pt': 'China', 'nl': 'China', ...  35.000000  105.000000
# 46  {'br': 'Ilha Christmas', 'pt': 'Ilha do Natal'... -10.500000  105.666667
# 47  {'br': 'Ilhas Cocos', 'pt': 'Ilhas dos Cocos',... -12.500000   96.833333
# 48  {'br': 'Colômbia', 'pt': 'Colômbia', 'nl': 'Co...   4.000000  -72.000000
# 49  {'br': 'Comores', 'pt': 'Comores', 'nl': 'Como... -12.166667   44.250000
#
#    emoji           emojiU                                             states
# 0     🇦🇫  U+1F1E6 U+1F1EB  [{'id': 3901, 'name': 'Badakhshan', 'state_cod...
# 1     🇦🇽  U+1F1E6 U+1F1FD                                                 []
# 2     🇦🇱  U+1F1E6 U+1F1F1  [{'id': 603, 'name': 'Berat County', 'state_co...
# 3     🇩🇿  U+1F1E9 U+1F1FF  [{'id': 1118, 'name': 'Adrar', 'state_code': '...
# 4     🇦🇸  U+1F1E6 U+1F1F8                                                 []
# 5     🇦🇩  U+1F1E6 U+1F1E9  [{'id': 488, 'name': 'Andorra la Vella', 'stat...
# 6     🇦🇴  U+1F1E6 U+1F1F4  [{'id': 221, 'name': 'Bengo Province', 'state_...
# 7     🇦🇮  U+1F1E6 U+1F1EE                                                 []
# 8     🇦🇶  U+1F1E6 U+1F1F6                                                 []
# 9     🇦🇬  U+1F1E6 U+1F1EC  [{'id': 3708, 'name': 'Barbuda', 'state_code':...
# 10    🇦🇷  U+1F1E6 U+1F1F7  [{'id': 4880, 'name': 'Autonomous City Of Buen...
# 11    🇦🇲  U+1F1E6 U+1F1F2  [{'id': 2023, 'name': 'Aragatsotn Region', 'st...
# 12    🇦🇼  U+1F1E6 U+1F1FC                                                 []
# 13    🇦🇺  U+1F1E6 U+1F1FA  [{'id': 3907, 'name': 'Australian Capital Terr...
# 14    🇦🇹  U+1F1E6 U+1F1F9  [{'id': 2062, 'name': 'Burgenland', 'state_cod...
# 15    🇦🇿  U+1F1E6 U+1F1FF  [{'id': 540, 'name': 'Absheron District', 'sta...
# 16    🇧🇸  U+1F1E7 U+1F1F8  [{'id': 3601, 'name': 'Acklins', 'state_code':...
# 17    🇧🇭  U+1F1E7 U+1F1ED  [{'id': 1992, 'name': 'Capital Governorate', '...
# 18    🇧🇩  U+1F1E7 U+1F1E9  [{'id': 796, 'name': 'Bagerhat District', 'sta...
# 19    🇧🇧  U+1F1E7 U+1F1E7  [{'id': 1228, 'name': 'Christ Church', 'state_...
# 20    🇧🇾  U+1F1E7 U+1F1FE  [{'id': 2959, 'name': 'Brest Region', 'state_c...
# 21    🇧🇪  U+1F1E7 U+1F1EA  [{'id': 1381, 'name': 'Antwerp', 'state_code':...
# 22    🇧🇿  U+1F1E7 U+1F1FF  [{'id': 264, 'name': 'Belize District', 'state...
# 23    🇧🇯  U+1F1E7 U+1F1EF  [{'id': 3077, 'name': 'Alibori Department', 's...
# 24    🇧🇲  U+1F1E7 U+1F1F2  [{'id': 4860, 'name': 'Devonshire Parish', 'st...
# 25    🇧🇹  U+1F1E7 U+1F1F9  [{'id': 240, 'name': 'Bumthang District', 'sta...
# 26    🇧🇴  U+1F1E7 U+1F1F4  [{'id': 3375, 'name': 'Beni Department', 'stat...
# 27    🇧🇶  U+1F1E7 U+1F1F6                                                 []
# 28    🇧🇦  U+1F1E7 U+1F1E6  [{'id': 472, 'name': 'Bosnian Podrinje Canton'...
# 29    🇧🇼  U+1F1E7 U+1F1FC  [{'id': 3067, 'name': 'Central District', 'sta...
# 30    🇧🇻  U+1F1E7 U+1F1FB                                                 []
# 31    🇧🇷  U+1F1E7 U+1F1F7  [{'id': 2012, 'name': 'Acre', 'state_code': 'A...
# 32    🇮🇴  U+1F1EE U+1F1F4                                                 []
# 33    🇧🇳  U+1F1E7 U+1F1F3  [{'id': 1217, 'name': 'Belait District', 'stat...
# 34    🇧🇬  U+1F1E7 U+1F1EC  [{'id': 4699, 'name': 'Blagoevgrad Province', ...
# 35    🇧🇫  U+1F1E7 U+1F1EB  [{'id': 3160, 'name': 'Balé Province', 'state_...
# 36    🇧🇮  U+1F1E7 U+1F1EE  [{'id': 3196, 'name': 'Bubanza Province', 'sta...
# 37    🇰🇭  U+1F1F0 U+1F1ED  [{'id': 3984, 'name': 'Banteay Meanchey Provin...
# 38    🇨🇲  U+1F1E8 U+1F1F2  [{'id': 2663, 'name': 'Adamawa', 'state_code':...
# 39    🇨🇦  U+1F1E8 U+1F1E6  [{'id': 872, 'name': 'Alberta', 'state_code': ...
# 40    🇨🇻  U+1F1E8 U+1F1FB  [{'id': 2994, 'name': 'Barlavento Islands', 's...
# 41    🇰🇾  U+1F1F0 U+1F1FE                                                 []
# 42    🇨🇫  U+1F1E8 U+1F1EB  [{'id': 1259, 'name': 'Bamingui-Bangoran Prefe...
# 43    🇹🇩  U+1F1F9 U+1F1E9  [{'id': 3583, 'name': 'Bahr el Gazel', 'state_...
# 44    🇨🇱  U+1F1E8 U+1F1F1  [{'id': 2832, 'name': 'Antofagasta Region', 's...
# 45    🇨🇳  U+1F1E8 U+1F1F3  [{'id': 2251, 'name': 'Anhui', 'state_code': '...
# 46    🇨🇽  U+1F1E8 U+1F1FD                                                 []
# 47    🇨🇨  U+1F1E8 U+1F1E8                                                 []
# 48    🇨🇴  U+1F1E8 U+1F1F4  [{'id': 2895, 'name': 'Amazonas Department', '...
# 49    🇰🇲  U+1F1F0 U+1F1F2  [{'id': 2821, 'name': 'Anjouan', 'state_code':...

# %%
full_df = full_df.query('name == "South Africa"')
full_df.head(50)
# Out:
#       id          name iso3 iso2 phone_code   capital currency  \
# 206  204  South Africa  ZAF   ZA         27  Pretoria      ZAR
#
#     currency_symbol  tld        native  region        subregion  \
# 206               R  .za  South Africa  Africa  Southern Africa
#
#                                              timezones  \
# 206  [{'zoneName': 'Africa/Johannesburg', 'gmtOffse...
#
#                                           translations  latitude  longitude  \
# 206  {'br': 'República Sul-Africana', 'pt': 'Repúbl...     -29.0       24.0
#
#     emoji           emojiU                                             states
# 206    🇿🇦  U+1F1FF U+1F1E6  [{'id': 938, 'name': 'Eastern Cape', 'state_co...

# %%
def africa():
    df = full_df.query('region == "Africa"')
    df = df.drop(['timezones', 'translations', 'states', 'emojiU', 'native', 'tld', 'id', 'iso3', 'iso2', 'currency_symbol', 'currency', 'phone_code', 'subregion', 'region',], axis = 1)
    return df
africa().head()
# Out:
#                               name       capital  latitude  longitude emoji
# 3                          Algeria       Algiers      28.0       3.00    🇩🇿
# 6                           Angola        Luanda     -12.5      18.50    🇦🇴
# 23                           Benin    Porto-Novo       9.5       2.25    🇧🇯
# 29                        Botswana      Gaborone     -22.0      24.00    🇧🇼
# 32  British Indian Ocean Territory  Diego Garcia      -6.0      71.50    🇮🇴

# %%
def asia():
    df = full_df.query('region == "Asia"')
    df = df.drop(['timezones', 'translations', 'states', 'emojiU', 'native', 'tld', 'id', 'iso3', 'iso2', 'currency_symbol', 'currency', 'phone_code', 'subregion', 'region',], axis = 1)
    return df
asia().head()
# Out:
#            name  capital  latitude  longitude emoji
# 0   Afghanistan    Kabul      33.0      65.00    🇦🇫
# 11      Armenia  Yerevan      40.0      45.00    🇦🇲
# 15   Azerbaijan     Baku      40.5      47.50    🇦🇿
# 17      Bahrain   Manama      26.0      50.55    🇧🇭
# 18   Bangladesh    Dhaka      24.0      90.00    🇧🇩

# %%
def oceania():
    df = full_df.query('region == "Oceania"')
    df = df.drop(['timezones', 'translations', 'states', 'emojiU', 'native', 'tld', 'id', 'iso3', 'iso2', 'currency_symbol', 'currency', 'phone_code', 'subregion', 'region',], axis = 1)
    return df
oceania().head()
# Out:
#                        name           capital   latitude   longitude emoji
# 4            American Samoa         Pago Pago -14.333333 -170.000000    🇦🇸
# 13                Australia          Canberra -27.000000  133.000000    🇦🇺
# 46         Christmas Island  Flying Fish Cove -10.500000  105.666667    🇨🇽
# 47  Cocos (Keeling) Islands       West Island -12.500000   96.833333    🇨🇨
# 52             Cook Islands            Avarua -21.233333 -159.766667    🇨🇰

# %%
def europe():
    df = full_df.query('region == "Europe"')
    df = df.drop(['timezones', 'translations', 'states', 'emojiU', 'native', 'tld', 'id', 'iso3', 'iso2', 'currency_symbol', 'currency', 'phone_code', 'subregion', 'region',], axis = 1)
    return df
europe().head()Americas
# Out:
#              name           capital   latitude  longitude emoji
# 1   Aland Islands         Mariehamn  60.116667  19.900000    🇦🇽
# 2         Albania            Tirana  41.000000  20.000000    🇦🇱
# 5         Andorra  Andorra la Vella  42.500000   1.500000    🇦🇩
# 14        Austria            Vienna  47.333333  13.333333    🇦🇹
# 20        Belarus             Minsk  53.000000  28.000000    🇧🇾

# %%
def americas():
    df = full_df.query('region == "Americas"')
    df = df.drop(['timezones', 'translations', 'states', 'emojiU', 'native', 'tld', 'id', 'iso3', 'iso2', 'currency_symbol', 'currency', 'phone_code', 'subregion', 'region',], axis = 1)
    return df
americas().head()
# Out:
#                    name       capital  latitude  longitude emoji
# 7              Anguilla    The Valley     18.25 -63.166667    🇦🇮
# 9   Antigua And Barbuda    St. John's     17.05 -61.800000    🇦🇬
# 10            Argentina  Buenos Aires    -34.00 -64.000000    🇦🇷
# 12                Aruba    Oranjestad     12.50 -69.966667    🇦🇼
# 16          Bahamas The        Nassau     24.25 -76.000000    🇧🇸

# %%
def polar():
    df = full_df.query('region == "Polar"')
    df = df.drop(['timezones', 'translations', 'states', 'emojiU', 'native', 'tld', 'id', 'iso3', 'iso2', 'currency_symbol', 'currency', 'phone_code', 'subregion', 'region',], axis = 1)
    return df
polar().head()
# Out:
#          name capital  latitude  longitude emoji
# 8  Antarctica            -74.65       4.48    🇦🇶

# %% [markdown]
# ### Sub-regions

# %%
def americas():
    df = full_df.query('region == "Americas"')
    df = df.drop(['timezones', 'translations', 'states', 'emojiU', 'native', 'tld', 'id', 'iso3', 'iso2', 'currency_symbol', 'currency', 'phone_code', 'subregion', 'region',], axis = 1)
    return df
americas().head()
# Out:
#                    name       capital  latitude  longitude emoji
# 7              Anguilla    The Valley     18.25 -63.166667    🇦🇮
# 9   Antigua And Barbuda    St. John's     17.05 -61.800000    🇦🇬
# 10            Argentina  Buenos Aires    -34.00 -64.000000    🇦🇷
# 12                Aruba    Oranjestad     12.50 -69.966667    🇦🇼
# 16          Bahamas The        Nassau     24.25 -76.000000    🇧🇸

# %%
def south_asia():
    df = full_df.query('subregion == "Southern Asia"')
    df = df.drop(['timezones', 'translations', 'states', 'emojiU', 'native', 'tld', 'id', 'iso3', 'iso2', 'currency_symbol', 'currency', 'phone_code', 'subregion', 'region',], axis = 1)
    return df
south_asia().head()
# Out:
#             name    capital  latitude  longitude emoji
# 0    Afghanistan      Kabul      33.0       65.0    🇦🇫
# 18    Bangladesh      Dhaka      24.0       90.0    🇧🇩
# 25        Bhutan    Thimphu      27.5       90.5    🇧🇹
# 102        India  New Delhi      20.0       77.0    🇮🇳
# 104         Iran     Tehran      32.0       53.0    🇮🇷

# %%
def northern_europe():
    df = full_df.query('subregion == "Northern Europe"')
    df = df.drop(['timezones', 'translations', 'states', 'emojiU', 'native', 'tld', 'id', 'iso3', 'iso2', 'currency_symbol', 'currency', 'phone_code', 'subregion', 'region',], axis = 1)
    return df
northern_europe().head()
# Out:
#              name     capital   latitude  longitude emoji
# 1   Aland Islands   Mariehamn  60.116667       19.9    🇦🇽
# 60        Denmark  Copenhagen  56.000000       10.0    🇩🇰
# 70        Estonia     Tallinn  59.000000       26.0    🇪🇪
# 73  Faroe Islands    Torshavn  62.000000       -7.0    🇫🇴
# 75        Finland    Helsinki  64.000000       26.0    🇫🇮

# %%
def northern_africa():
    df = full_df.query('subregion == "Northern Africa"')
    df = df.drop(['timezones', 'translations', 'states', 'emojiU', 'native', 'tld', 'id', 'iso3', 'iso2', 'currency_symbol', 'currency', 'phone_code', 'subregion', 'region',], axis = 1)
    return df
northern_africa().head()
# Out:
#         name   capital  latitude  longitude emoji
# 3    Algeria   Algiers      28.0        3.0    🇩🇿
# 66     Egypt     Cairo      27.0       30.0    🇪🇬
# 126    Libya  Tripolis      25.0       17.0    🇱🇾
# 151  Morocco     Rabat      32.0       -5.0    🇲🇦
# 211    Sudan  Khartoum      15.0       30.0    🇸🇩

# %%
def south_europe():
    df = full_df.query('subregion == "Southern Europe"')
    df = df.drop(['timezones', 'translations', 'states', 'emojiU', 'native', 'tld', 'id', 'iso3', 'iso2', 'currency_symbol', 'currency', 'phone_code', 'subregion', 'region',], axis = 1)
    return df
south_europe().head()
# Out:
#                       name           capital   latitude  longitude emoji
# 2                  Albania            Tirana  41.000000       20.0    🇦🇱
# 5                  Andorra  Andorra la Vella  42.500000        1.5    🇦🇩
# 28  Bosnia and Herzegovina          Sarajevo  44.000000       18.0    🇧🇦
# 55      Croatia (Hrvatska)            Zagreb  45.166667       15.5    🇭🇷
# 58                  Cyprus           Nicosia  35.000000       33.0    🇨🇾

# %%
def polynesia():
    df = full_df.query('subregion == "Polynesia"')
    df = df.drop(['timezones', 'translations', 'states', 'emojiU', 'native', 'tld', 'id', 'iso3', 'iso2', 'currency_symbol', 'currency', 'phone_code', 'subregion', 'region',], axis = 1)
    return df
polynesia().head()
# Out:
#                  name    capital   latitude   longitude emoji
# 4      American Samoa  Pago Pago -14.333333 -170.000000    🇦🇸
# 52       Cook Islands     Avarua -21.233333 -159.766667    🇨🇰
# 78   French Polynesia    Papeete -15.000000 -140.000000    🇵🇫
# 163              Niue      Alofi -19.033333 -169.866667    🇳🇺
# 176   Pitcairn Island  Adamstown -25.066667 -130.100000    🇵🇳

# %%
def middle_africa():
    df = full_df.query('subregion == "Middle Africa"')
    df = df.drop(['timezones', 'translations', 'states', 'emojiU', 'native', 'tld', 'id', 'iso3', 'iso2', 'currency_symbol', 'currency', 'phone_code', 'subregion', 'region',], axis = 1)
    return df
middle_africa().head()
# Out:
#                         name      capital  latitude  longitude emoji
# 6                     Angola       Luanda     -12.5       18.5    🇦🇴
# 38                  Cameroon      Yaounde       6.0       12.0    🇨🇲
# 42  Central African Republic       Bangui       7.0       21.0    🇨🇫
# 43                      Chad    N'Djamena      15.0       19.0    🇹🇩
# 50                     Congo  Brazzaville      -1.0       15.0    🇨🇬

# %%
def caribbean():
    df = full_df.query('subregion == "Caribbean"')
    df = df.drop(['timezones', 'translations', 'states', 'emojiU', 'native', 'tld', 'id', 'iso3', 'iso2', 'currency_symbol', 'currency', 'phone_code', 'subregion', 'region',], axis = 1)
    return df
caribbean().head()
# Out:
#                    name     capital   latitude  longitude emoji
# 7              Anguilla  The Valley  18.250000 -63.166667    🇦🇮
# 9   Antigua And Barbuda  St. John's  17.050000 -61.800000    🇦🇬
# 12                Aruba  Oranjestad  12.500000 -69.966667    🇦🇼
# 16          Bahamas The      Nassau  24.250000 -76.000000    🇧🇸
# 19             Barbados  Bridgetown  13.166667 -59.533333    🇧🇧

# %%
def south_america():
    df = full_df.query('subregion == "South America"')
    df = df.drop(['timezones', 'translations', 'states', 'emojiU', 'native', 'tld', 'id', 'iso3', 'iso2', 'currency_symbol', 'currency', 'phone_code', 'subregion', 'region',], axis = 1)
    return df
south_america().head()
# Out:
#          name       capital  latitude  longitude emoji
# 10  Argentina  Buenos Aires     -34.0      -64.0    🇦🇷
# 26    Bolivia         Sucre     -17.0      -65.0    🇧🇴
# 31     Brazil      Brasilia     -10.0      -55.0    🇧🇷
# 44      Chile      Santiago     -30.0      -71.0    🇨🇱
# 48   Colombia        Bogota       4.0      -72.0    🇨🇴

# %%
def western_asia():
    df = full_df.query('subregion == "Western Asia"')
    df = df.drop(['timezones', 'translations', 'states', 'emojiU', 'native', 'tld', 'id', 'iso3', 'iso2', 'currency_symbol', 'currency', 'phone_code', 'subregion', 'region',], axis = 1)
    return df
western_asia().head()
# Out:
#            name  capital  latitude  longitude emoji
# 11      Armenia  Yerevan      40.0      45.00    🇦🇲
# 15   Azerbaijan     Baku      40.5      47.50    🇦🇿
# 17      Bahrain   Manama      26.0      50.55    🇧🇭
# 82      Georgia  Tbilisi      42.0      43.50    🇬🇪
# 105        Iraq  Baghdad      33.0      44.00    🇮🇶

# %%
def western_europe():
    df = full_df.query('subregion == "Western Europe"')
    df = df.drop(['timezones', 'translations', 'states', 'emojiU', 'native', 'tld', 'id', 'iso3', 'iso2', 'currency_symbol', 'currency', 'phone_code', 'subregion', 'region',], axis = 1)
    return df
western_europe().head()
# Out:
#               name   capital   latitude  longitude emoji
# 14         Austria    Vienna  47.333333  13.333333    🇦🇹
# 21         Belgium  Brussels  50.833333   4.000000    🇧🇪
# 76          France     Paris  46.000000   2.000000    🇫🇷
# 83         Germany    Berlin  51.000000   9.000000    🇩🇪
# 127  Liechtenstein     Vaduz  47.266667   9.533333    🇱🇮

# %%
def central_america():
    df = full_df.query('subregion == "Central America"')
    df = df.drop(['timezones', 'translations', 'states', 'emojiU', 'native', 'tld', 'id', 'iso3', 'iso2', 'currency_symbol', 'currency', 'phone_code', 'subregion', 'region',], axis = 1)
    return df
central_america().head()
# Out:
#            name         capital   latitude  longitude emoji
# 22       Belize        Belmopan  17.250000 -88.750000    🇧🇿
# 53   Costa Rica        San Jose  10.000000 -84.000000    🇨🇷
# 67  El Salvador    San Salvador  13.833333 -88.916667    🇸🇻
# 91    Guatemala  Guatemala City  15.500000 -90.250000    🇬🇹
# 98     Honduras     Tegucigalpa  15.000000 -86.500000    🇭🇳

# %%
def western_africa():
    df = full_df.query('subregion == "Western Africa"')
    df = df.drop(['timezones', 'translations', 'states', 'emojiU', 'native', 'tld', 'id', 'iso3', 'iso2', 'currency_symbol', 'currency', 'phone_code', 'subregion', 'region',], axis = 1)
    return df
western_africa().head()
# Out:
#                            name       capital   latitude  longitude emoji
# 23                        Benin    Porto-Novo   9.500000   2.250000    🇧🇯
# 35                 Burkina Faso   Ouagadougou  13.000000  -2.000000    🇧🇫
# 40                   Cape Verde         Praia  16.000000 -24.000000    🇨🇻
# 54  Cote D'Ivoire (Ivory Coast)  Yamoussoukro   8.000000  -5.000000    🇨🇮
# 81                   Gambia The        Banjul  13.466667 -16.566667    🇬🇲

# %%
def northern_america():
    df = full_df.query('subregion == "Northern America"')
    df = df.drop(['timezones', 'translations', 'states', 'emojiU', 'native', 'tld', 'id', 'iso3', 'iso2', 'currency_symbol', 'currency', 'phone_code', 'subregion', 'region',], axis = 1)
    return df
northern_america().head()
# Out:
#                           name       capital   latitude  longitude emoji
# 24                     Bermuda      Hamilton  32.333333 -64.750000    🇧🇲
# 39                      Canada        Ottawa  60.000000 -95.000000    🇨🇦
# 87                   Greenland          Nuuk  72.000000 -40.000000    🇬🇱
# 188  Saint Pierre and Miquelon  Saint-Pierre  46.833333 -56.333333    🇵🇲
# 235              United States    Washington  38.000000 -97.000000    🇺🇸

# %%
def southern_africa():
    df = full_df.query('subregion == "Southern Africa"')
    df = df.drop(['timezones', 'translations', 'states', 'emojiU', 'native', 'tld', 'id', 'iso3', 'iso2', 'currency_symbol', 'currency', 'phone_code', 'subregion', 'region',], axis = 1)
    return df
southern_africa().head()
# Out:
#                             name            capital  latitude  longitude emoji
# 29                      Botswana           Gaborone    -22.00     24.000    🇧🇼
# 79   French Southern Territories  Port-aux-Francais    -49.25     69.167    🇹🇫
# 124                      Lesotho             Maseru    -29.50     28.500    🇱🇸
# 154                      Namibia           Windhoek    -22.00     17.000    🇳🇦
# 206                 South Africa           Pretoria    -29.00     24.000    🇿🇦

# %%
def eastern_africa():
    df = full_df.query('subregion == "Eastern Africa"')
    df = df.drop(['timezones', 'translations', 'states', 'emojiU', 'native', 'tld', 'id', 'iso3', 'iso2', 'currency_symbol', 'currency', 'phone_code', 'subregion', 'region',], axis = 1)
    return df
eastern_africa().head()
# Out:
#                               name       capital   latitude  longitude emoji
# 32  British Indian Ocean Territory  Diego Garcia  -6.000000      71.50    🇮🇴
# 36                         Burundi     Bujumbura  -3.500000      30.00    🇧🇮
# 49                         Comoros        Moroni -12.166667      44.25    🇰🇲
# 61                        Djibouti      Djibouti  11.500000      43.00    🇩🇯
# 69                         Eritrea        Asmara  15.000000      39.00    🇪🇷

# %%
def south_eastern_asia():
    df = full_df.query('subregion == "South-Eastern Asia"')
    df = df.drop(['timezones', 'translations', 'states', 'emojiU', 'native', 'tld', 'id', 'iso3', 'iso2', 'currency_symbol', 'currency', 'phone_code', 'subregion', 'region',], axis = 1)
    return df
south_eastern_asia().head()
# Out:
#            name              capital   latitude   longitude emoji
# 33       Brunei  Bandar Seri Begawan   4.500000  114.666667    🇧🇳
# 37     Cambodia           Phnom Penh  13.000000  105.000000    🇰🇭
# 64   East Timor                 Dili  -8.833333  125.916667    🇹🇱
# 103   Indonesia              Jakarta  -5.000000  120.000000    🇮🇩
# 121        Laos            Vientiane  18.000000  105.000000    🇱🇦

# %%
def eastern_europe():
    df = full_df.query('subregion == "Eastern Europe"')
    df = df.drop(['timezones', 'translations', 'states', 'emojiU', 'native', 'tld', 'id', 'iso3', 'iso2', 'currency_symbol', 'currency', 'phone_code', 'subregion', 'region',], axis = 1)
    return df
eastern_europe().head()
# Out:
#                name   capital   latitude  longitude emoji
# 20          Belarus     Minsk  53.000000  28.000000    🇧🇾
# 34         Bulgaria     Sofia  43.000000  25.000000    🇧🇬
# 59   Czech Republic    Prague  49.750000  15.500000    🇨🇿
# 100         Hungary  Budapest  47.000000  20.000000    🇭🇺
# 118          Kosovo  Pristina  42.561291  20.340304    🇽🇰

# %%
def eastern_asia():
    df = full_df.query('subregion == "Eastern Asia"')
    df = df.drop(['timezones', 'translations', 'states', 'emojiU', 'native', 'tld', 'id', 'iso3', 'iso2', 'currency_symbol', 'currency', 'phone_code', 'subregion', 'region',], axis = 1)
    return df
eastern_asia().head()
# Out:
#                  name    capital  latitude   longitude emoji
# 45              China    Beijing     35.00  105.000000    🇨🇳
# 99   Hong Kong S.A.R.  Hong Kong     22.25  114.166667    🇭🇰
# 110             Japan      Tokyo     36.00  138.000000    🇯🇵
# 116       Korea North  Pyongyang     40.00  127.000000    🇰🇵
# 117       Korea South      Seoul     37.00  127.500000    🇰🇷

# %%
def australia_newzealand():
    df = full_df.query('subregion == "Australia and New Zealand"')
    df = df.drop(['timezones', 'translations', 'states', 'emojiU', 'native', 'tld', 'id', 'iso3', 'iso2', 'currency_symbol', 'currency', 'phone_code', 'subregion', 'region',], axis = 1)
    return df
australia_newzealand().head()
# Out:
#                         name           capital   latitude   longitude emoji
# 13                 Australia          Canberra -27.000000  133.000000    🇦🇺
# 46          Christmas Island  Flying Fish Cove -10.500000  105.666667    🇨🇽
# 47   Cocos (Keeling) Islands       West Island -12.500000   96.833333    🇨🇨
# 159              New Zealand        Wellington -41.000000  174.000000    🇳🇿
# 164           Norfolk Island          Kingston -29.033333  167.950000    🇳🇫

# %%
def melanesia():
    df = full_df.query('subregion == "Melanesia"')
    df = df.drop(['timezones', 'translations', 'states', 'emojiU', 'native', 'tld', 'id', 'iso3', 'iso2', 'currency_symbol', 'currency', 'phone_code', 'subregion', 'region',], axis = 1)
    return df
melanesia().head()
# Out:
#                  name       capital  latitude  longitude emoji
# 74       Fiji Islands          Suva     -18.0      175.0    🇫🇯
# 158     New Caledonia        Noumea     -21.5      165.5    🇳🇨
# 172  Papua new Guinea  Port Moresby      -6.0      147.0    🇵🇬
# 204   Solomon Islands       Honiara      -8.0      159.0    🇸🇧
# 239           Vanuatu     Port Vila     -16.0      167.0    🇻🇺

# %%
def central_asia():
    df = full_df.query('subregion == "Central Asia"')
    df = df.drop(['timezones', 'translations', 'states', 'emojiU', 'native', 'tld', 'id', 'iso3', 'iso2', 'currency_symbol', 'currency', 'phone_code', 'subregion', 'region',], axis = 1)
    return df
central_asia().head()
# Out:
#              name   capital  latitude  longitude emoji
# 113    Kazakhstan    Astana      48.0       68.0    🇰🇿
# 120    Kyrgyzstan   Bishkek      41.0       75.0    🇰🇬
# 219    Tajikistan  Dushanbe      39.0       71.0    🇹🇯
# 228  Turkmenistan  Ashgabat      40.0       60.0    🇹🇲
# 238    Uzbekistan  Tashkent      41.0       64.0    🇺🇿

# %%
def countries():
    df = full_df.drop(['timezones', 'translations', 'states', 'emojiU', 'native', 'tld', 'id', 'iso3', 'iso2', 'currency_symbol', 'currency', 'phone_code', 'subregion', 'region',], axis = 1)
    return df
countries().head()
# Out:
#              name    capital   latitude  longitude emoji
# 0     Afghanistan      Kabul  33.000000       65.0    🇦🇫
# 1   Aland Islands  Mariehamn  60.116667       19.9    🇦🇽
# 2         Albania     Tirana  41.000000       20.0    🇦🇱
# 3         Algeria    Algiers  28.000000        3.0    🇩🇿
# 4  American Samoa  Pago Pago -14.333333     -170.0    🇦🇸
